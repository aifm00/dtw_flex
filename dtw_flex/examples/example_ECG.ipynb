# %%
#%pip install ipympl
#import ipympl
# %matplotlib ipympl
from dtw_flex import Dtw
import numpy as np

# %%
nref_raw = 15
nquery = 50
dtw_obj = Dtw(nref_raw=nref_raw, nquery=nquery)

# %%
dtw_obj.ref = np.array([0.2, 0.2, 0.2, 0.3, 0.2, 0.12, 1., 0., 0.2, 0.2,0.33,0.5,0.34,0.2,0.2,0.2,0.2]) #ECG
#dtw_obj.rep_ref[dtw_obj.nref // 2] = 1
dtw_obj.ref_plotset(hide_endpoints=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dtw_obj.query = np.random.rand(nquery)
id_insert = 6
dtw_obj.query[id_insert:id_insert + dtw_obj.nref] = dtw_obj.query[id_insert: id_insert + dtw_obj.nref] + dtw_obj.ref * 5
dtw_obj.query[30:31] = 6
dtw_obj.query_plotset()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dtw_obj.run_dtw(plt_fit = True, plt_match = True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
